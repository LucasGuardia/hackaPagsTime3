# %%
# Célula 1: Imports e Configuração do Caminho (Path)

import sys
import os

# --- Adiciona a pasta 'src' ao path do Python ---
project_root = os.path.abspath(os.path.join('..'))
src_path = os.path.join(project_root, 'src')
if src_path not in sys.path:
    sys.path.append(src_path)
# -----------------------------------------------

# Importa NOSSA função de treino (da FASE 5)
from models.train_churn_model import train_and_save_churn_model

print("Módulos importados. Pronto para treinar o modelo de Churn.")

# %%
# Célula 2: Executar o Treinamento da FASE 5

# Esta única função vai fazer tudo:
# 1. Carregar 'dados/processed/features_churn_clientes.csv'
# 2. Selecionar features (X) e alvo (y)
# 3. Treinar o modelo (com balanceamento)
# 4. Salvar o artefacto em 'modelos/'

train_and_save_churn_model()
